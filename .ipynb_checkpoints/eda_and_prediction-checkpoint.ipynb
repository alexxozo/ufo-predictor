# %% [markdown]
# <h1 style="text-align:center;">👽👽👽👽 UFO PREDICTION 👽👽👽👽</h1>

# %% [markdown]
# <img src="ufo.jpg">

# %% [markdown]
# <h1 style="text-align:center;">👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽👽</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Let's read the data 🕵🏻‍♂️

# %%
ufo_df = pd.read_csv('./data/scrubbed.csv', error_bad_lines=False, low_memory=False)

# %%
# %store ufo_df
ufo_df.info()
# Out:
# Stored 'ufo_df' (DataFrame)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %% [markdown]
# ### Let's change some column names for easy access 👌

# %%
ufo_df.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'comments', 'date posted', 'latitude',
#        'longitude '],
#       dtype='object')

# %%
ufo_df = ufo_df.rename(columns={'duration (seconds)': 'duration_seconds', 'duration (hours/min)': 'duration_hours', 'date posted': 'date_posted', 'longitude ': 'longitude'})
ufo_df.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration_seconds',
#        'duration_hours', 'comments', 'date_posted', 'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# ### Let's convert columns to correct types

# %%
ufo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   datetime          80332 non-null  object
#  1   city              80332 non-null  object
#  2   state             74535 non-null  object
#  3   country           70662 non-null  object
#  4   shape             78400 non-null  object
#  5   duration_seconds  80332 non-null  object
#  6   duration_hours    80332 non-null  object
#  7   comments          80317 non-null  object
#  8   date_posted       80332 non-null  object
#  9   latitude          80332 non-null  object
#  10  longitude         80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %%
def convert_int_from_string(string):
    string = re.sub("[^0-9]", "", string)
    return int(string)

def convert_float_from_string(string):
    string = re.sub(r"[a-zA-Z]", "", string)
    string = re.sub(r"\s+", "", string)
    if len(string) == 0:
        return 0.1
    print(string)
    return float(string)

# %%
import re
# run one time only
ufo_df['duration_seconds'] = ufo_df['duration_seconds'].apply(convert_int_from_string)
ufo_df['latitude'] = ufo_df['latitude'].apply(convert_float_from_string)
ufo_df['longitude'] = ufo_df['longitude'].apply(convert_float_from_string)
# Out:
# 29.8830556
# 29.38421
# 53.2
# 28.9783333
# 21.4180556
# 36.5950000
# 51.434722
# 41.1175000
# 33.5861111
# 30.2947222
# 33.9163889
# 35.2333333
# 40.6686111
# 37.1536111
# 35.8238889
# 36.8430556
# 42.5377778
# 41.3252778
# 32.364167
# 42.3916667
# 51.5
# 36.3883333
# 37.0583333
# 33.9791667
# 42.0866667
# 35.7913889
# 38.5816667
# 40.6883333
# 34.6777778
# 47.9791667
# 33.8925000
# 42.0252778
# 64.8377778
# 40.4405556
# 49.883333
# 42.6288889
# 39.7686111
# 50.503887
# 42.1013889
# 33.6058333
# 43.0986111
# 46.2397222
# 40.2680556
# 47.6105556
# 46.2272222
# 47.6063889
# 43.133333
# 56.116667
# 36.231719
# 43.6952778
# 40.743756
# 40.8852778
# 47.3483333
# 35.3733333
# 34.7391667
# 46.857905
# 39.1141667
# 43.4666667
# 35.2650000
# 44.9800000
# 32.9536111
# 44.8519444
# 35.1894444
# 41.462072
# 44.448881
# 33.1383333
# 42.4055556
# 41.0983333
# 42.9072222
# 47.2530556
# 42.9638889
# 38.9488889
# 33.6125000
# 42.3952778
# 38.0050000
# 41.0533333
# 39.1155556
# 41.35424
# 39.4141667
# 43.9827778
# 37.5536111
# 35.584324
# 41.1383333
# 41.7858333
# 38.9980556
# 42.4775000
# 41.921111
# 43.0630556
# 14.416667
# 39.9866667
# 39.9611111
# 38.9716667
# 39.1625000
# 40.2736111
# 40.6263889
# 39.9450000
# 44.2911111
# 44.4908333
# 41.0358333
# 44.7972222
# 35.967677
# 33.4222222
# 38.9716667
# 41.4994444
# 42.566667
# 43.8019444
# 40.7141667
# 40.7683333
# 53.5
# 33.6888889
# 45.073601
# 35.6008333
# 38.787509
# 33.8358333
# 40.7141667
# 28.0391667
# 38.0683333
# 40.7141667
# 30.2669444
# 45.4316667
# 27.8002778
# 33.5386111
# 40.7944444
# 32.8438889
# 34.1283333
# 47.6063889
# 37.5530556
# 36.589245
# 39.6133333
# 26.7052778
# 37.1305556
# 34.935469
# 43.2
# 41.1572222
# 40.0336111
# 34.2255556
# 35.9525000
# 31.4722222
# 51.083333
# 30.680025
# 31.5491667
# 32.6858333
# 47.6063889
# 33.4483333
# 39.5533333
# 54.133333
# 36.778261
# 42.108914
# 38.6269444
# 45.4872222
# 39.4652778
# 39.3372222
# 42.3383333
# 39.6477778
# 52.481138
# 51.025876
# 33.4511111
# 43.2219444
# 33.6058333
# 33.6888889
# 37.191531
# 41.1669444
# 37.7975000
# 36.1750000
# 35.6225000
# 35.6225000
# 28.2394444
# 41.9441667
# 30.4505556
# 34.07362
# 35.9605556
# 35.6266667
# 24.861462
# 25.7738889
# 41.6997222
# 35.5847222
# 44.6563889
# 32.9375000
# 40.4591667
# 27.2936111
# 44.9444444
# 43.0011111
# 26.2030556
# 43.1705556
# 40.7683333
# 40.6955556
# 41.1844444
# 41.4091667
# 29.7630556
# 35.9250000
# 32.8950000
# 41.3502778
# 49.15
# 39.3508333
# 40.995589
# 41.0813889
# 37.6922222
# 33.5966667
# 47.7425000
# 38.6822222
# 35.3338889
# 38.2558333
# 41.6458333
# 36.7797222
# 45.6797222
# 43.1705556
# 44.079162
# 40.0227778
# 40.7141667
# 38.4219444
# 30.2669444
# 35.0844444
# 40.9866667
# 33.3244444
# 39.7172222
# 40.8000000
# 40.1083333
# 43.6136111
# 44.8586111
# 48.0905556
# 44.8944444
# 53.166667
# 49.45
# 45.2166667
# 44.0466667
# 42.2430556
# 25.0861111
# 40.7141667
# 47.1041667
# 28.7555556
# 32.2216667
# 40.0394444
# 39.2902778
# 41.5733333
# 33.4483333
# 30.2669444
# 42.5294444
# 29.6513889
# 29.6513889
# 34.1597222
# 34.0975000
# 34.0788889
# 34.3675000
# 34.1463889
# 34.2255556
# 45.5236111
# 34.4208333
# 43.1547222
# 27.4986111
# 32.4805556
# 41.0358333
# 32.6400000
# 32.6400000
# 47.7575000
# 41.5261111
# 43.8013889
# 35.8455556
# 42.4250000
# 39.0991667
# 26.0391667
# 40.8258333
# 36.8466667
# 45.666667
# 42.3636111
# 38.8119444
# 35.6144444
# 40.8666667
# 35.4872222
# 35.8455556
# 35.7211111
# 40.7008333
# 36.2000000
# 34.2783333
# 40.5622222
# 41.6819444
# 40.7141667
# 33.4330556
# 34.2783333
# 32.7763889
# 34.2977778
# 36.8466667
# 42.8863889
# 41.0525000
# 32.7152778
# 30.5050000
# 53.25
# 40.858433
# 33.2097222
# 36.5297222
# 50.465843
# 29.6513889
# 34.367594
# 46.3
# 34.1013889
# 36.1658333
# 43.6136111
# 38.2972222
# 38.9011111
# 35.6527778
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-fdc8ae636f0d> in <module>
#       3 ufo_df['duration_seconds'] = ufo_df['duration_seconds'].apply(convert_int_from_string)
#       4 ufo_df['latitude'] = ufo_df['latitude'].apply(convert_float_from_string)
# ----> 5 ufo_df['longitude'] = ufo_df['longitude'].apply(convert_float_from_string)
#
# /opt/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-40-79d4f1d816ee> in convert_float_from_string(string)
#       4
#       5 def convert_float_from_string(string):
# ----> 6     string = re.sub(r"[a-zA-Z]", "", string)
#       7     string = re.sub(r"\s+", "", string)
#       8     if len(string) == 0:
#
# /opt/anaconda3/envs/python37/lib/python3.7/re.py in sub(pattern, repl, string, count, flags)
#     192     a callable, it's passed the Match object and must return
#     193     a replacement string to be used."""
# --> 194     return _compile(pattern, flags).sub(repl, string, count)
#     195
#     196 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
ufo_df.astype({'datetime': 'string',
               'city': 'string',
               'state': 'string',
               'country': 'string',
               'shape': 'string',
               'duration_seconds': 'int32',
               'duration_hours': 'string',
               'comments': 'string',
               'date_posted': 'string',
               'latitude': 'float'
              }).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   datetime          80332 non-null  string
#  1   city              80332 non-null  string
#  2   state             74535 non-null  string
#  3   country           70662 non-null  string
#  4   shape             78400 non-null  string
#  5   duration_seconds  80332 non-null  int32
#  6   duration_hours    80332 non-null  string
#  7   comments          80317 non-null  string
#  8   date_posted       80332 non-null  string
#  9   latitude          80332 non-null  float64
#  10  longitude         80332 non-null  float64
# dtypes: float64(2), int32(1), string(8)
# memory usage: 6.4 MB

# %% [markdown]
# ### Let's get rid of all null values

# %%
ufo_df.loc[ufo_df['state'].isnull(), 'state'] = '??'
ufo_df.loc[ufo_df['shape'].isnull(), 'shape'] = 'unknown'
ufo_df.loc[ufo_df['comments'].isnull(), 'comments'] = '??'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-0e7fb6b8d4f9> in <module>
# ----> 1 ufo_df.loc[ufo_df['state'].isnull(), 'state'] = '??'
#       2 ufo_df.loc[ufo_df['shape'].isnull(), 'shape'] = 'unknown'
#       3 ufo_df.loc[ufo_df['comments'].isnull(), 'comments'] = '??'
#
# /opt/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# /opt/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# /opt/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: 'state'

# %%
for i, row in ufo_df.iterrows():
    if row['country'] is None:
        if not row['state'] is None:
            ufo_df.ix[i]['country'] = 'us'
        else:
            ufo_df.ix[i]['country'] = '??'
# Out:
#   File "<ipython-input-57-07c3e67859e2>", line 4
#     ufo_df = ufo_df.apply(change_country, axis=1)
#          ^
# IndentationError: expected an indented block

# %%
ufo_df
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 80327    None
# 80328    None
# 80329    None
# 80330    None
# 80331    None
# Length: 80332, dtype: object

# %% [markdown]
# ### Let's clear the texts about the sightnings

# %%
import nltk
import unicodedata
nltk.download('stopwords')
nltk.download('wordnet')

def clean_text(text):
    wnl = nltk.stem.WordNetLemmatizer()
    text = (unicodedata.normalize('NFKD', text)
        .encode('ascii', 'ignore')
        .decode('utf-8', 'ignore'))
    text = re.sub(r'[^\w\s]', '', text) 
    text = re.sub(r'(http.+)', '', text)
    return text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/macbookpro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/macbookpro/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
ufo_df['clean_comments'] = ufo_df['comments'].apply(clean_text)

# %%
ufo_df['clean_comments'][0]
# Out:
# 'This event took place in early fall around 194950 It occurred after a Boy Scout meeting in the Baptist Church The Baptist Church sit'

# %% [markdown]
# ### Let's create some new columns

# %%
# Seasons of the ufo appearances
def output_season_from(x):
    x = int(x.split("/")[0])
    if x in range(3,6):
        return "Spring"
    if x in range(6,9):
        return "Summer"
    if x in range(9,12):
        return "Autumn"
    if x == 12 or x == 1 or x == 2:
        return "Winter"

ufo_df["season"] = ufo_df['datetime'].apply(output_season_from)
ufo_df.head(1)
# Out:
#            datetime        city state country     shape  duration_seconds  \
# 0  10/10/1949 20:30  san marcos    tx      us  cylinder              2700
#
#   duration_hours                                           comments  \
# 0     45 minutes  This event took place in early fall around 194...
#
#   date_posted   latitude  longitude  \
# 0   4/27/2004  29.883056 -97.941111
#
#                                       clean_comments  season
# 0  This event took place in early fall around 194...  Autumn

# %%
# Check out what colors the ufo have
def output_color_from(text):
    colors = ['black', 'white', 'red', 'green', 'yellow', 'blue', 'pink', 'gray', 'brown', 'orange', 'purple']
    for color in colors:
        if color in str(text).lower():
            return color
    return '??'
            
        
ufo_df['ufo_color'] = ufo_df['clean_comments'].apply(output_color_from)

ufo_df.head(1)
# Out:
#            datetime        city state country     shape  duration_seconds  \
# 0  10/10/1949 20:30  san marcos    tx      us  cylinder              2700
#
#   duration_hours                                           comments  \
# 0     45 minutes  This event took place in early fall around 194...
#
#   date_posted   latitude  longitude  \
# 0   4/27/2004  29.883056 -97.941111
#
#                                       clean_comments  season ufo_color
# 0  This event took place in early fall around 194...  Autumn       red

# %%
# Check out when the ufo have been seen by year
import datetime

def output_year_from(text):
    text = text.replace('24:00', '0:00')
    date = datetime.datetime.strptime(text, '%m/%d/%Y %H:%M').date()
    return date.year
            
        
ufo_df['event_year'] = ufo_df['datetime'].apply(output_year_from)

ufo_df.head(1)
# Out:
#            datetime        city state country     shape  duration_seconds  \
# 0  10/10/1949 20:30  san marcos    tx      us  cylinder              2700
#
#   duration_hours                                           comments  \
# 0     45 minutes  This event took place in early fall around 194...
#
#   date_posted   latitude  longitude  \
# 0   4/27/2004  29.883056 -97.941111
#
#                                       clean_comments  season ufo_color  \
# 0  This event took place in early fall around 194...  Autumn       red
#
#    event_year
# 0        1949

# %%
# Check out when the ufo have been seen by weekday
import datetime

def output_weekday_from(text):
    text = text.replace('24:00', '0:00')
    date = datetime.datetime.strptime(text, '%m/%d/%Y %H:%M').date()
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    return days[date.weekday()]
            
        
ufo_df['event_weekday'] = ufo_df['datetime'].apply(output_weekday_from)

ufo_df.head(1)
# Out:
#            datetime        city state country     shape  duration_seconds  \
# 0  10/10/1949 20:30  san marcos    tx      us  cylinder              2700
#
#   duration_hours                                           comments  \
# 0     45 minutes  This event took place in early fall around 194...
#
#   date_posted   latitude  longitude  \
# 0   4/27/2004  29.883056 -97.941111
#
#                                       clean_comments  season ufo_color  \
# 0  This event took place in early fall around 194...  Autumn       red
#
#    event_year event_weekday
# 0        1949        Monday

# %%
# Check out when the ufo have been seen by weekday
import datetime

def output_hour_from(text):
    text = text.replace('24:00', '0:00')
    hour = datetime.datetime.strptime(text, '%m/%d/%Y %H:%M').hour
    return hour
            
        
ufo_df['event_hour'] = ufo_df['datetime'].apply(output_hour_from)

ufo_df.head(1)
# Out:
#            datetime        city state country     shape  duration_seconds  \
# 0  10/10/1949 20:30  san marcos    tx      us  cylinder              2700
#
#   duration_hours                                           comments  \
# 0     45 minutes  This event took place in early fall around 194...
#
#   date_posted   latitude  longitude  \
# 0   4/27/2004  29.883056 -97.941111
#
#                                       clean_comments  season ufo_color  \
# 0  This event took place in early fall around 194...  Autumn       red
#
#    event_year event_weekday  event_hour
# 0        1949        Monday          20

# %% [markdown]
# ## In which season are ufos most frequent?

# %%
plt.subplots(figsize=(22,8))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = sns.countplot(x="season", data=ufo_df, order=ufo_df['season'].value_counts().index)

# %% [markdown]
# ## At what hour are ufos most frequent?

# %%
plt.subplots(figsize=(22,8))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = sns.countplot(x="event_hour", data=ufo_df, order=ufo_df['event_hour'].value_counts().index)

# %% [markdown]
# ## In which days of the week are ufos most frequent?

# %%
plt.subplots(figsize=(22,8))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = sns.countplot(x="event_weekday", data=ufo_df, order=ufo_df['event_weekday'].value_counts().index)

# %% [markdown]
# ## In what years of the week are ufos most frequent? (20 years span from 2012)

# %%
plt.subplots(figsize=(30,8))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = sns.countplot(x="event_year", data=ufo_df, order=ufo_df['event_year'].value_counts().index[:20])

# %% [markdown]
# ## In what countries are ufos most frequent?

# %%
plt.subplots(figsize=(22,8))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = sns.countplot(x="country", data=ufo_df, order=ufo_df['country'].value_counts().index)

# %% [markdown]
# ## In what states are ufos frequent?

# %%
plt.subplots(figsize=(40,8))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = sns.countplot(x="state", data=ufo_df, order=ufo_df['state'].value_counts().index[:30])

# %% [markdown]
# ## What shapes are ufos frequent?

# %%
plt.subplots(figsize=(22,8))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = sns.countplot(x="shape", data=ufo_df, order=ufo_df['shape'].value_counts().index[:15])

# %% [markdown]
# ## What colors are the ufos?

# %%
plt.subplots(figsize=(22,8))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = sns.countplot(x="ufo_color", data=ufo_df, order=ufo_df['ufo_color'].value_counts().index[:15])

# %% [markdown]
# ## How many seconds does an encounter last?

# %%
plt.subplots(figsize=(22,8))
duration_sec = [i for i in ufo_df["duration_seconds"].value_counts()]
duration_sec_list = []
for i in duration_sec:
    if i in range(0,16):
        duration_sec_list.append("0-15")
    if i in range(15,31):
        duration_sec_list.append("15-30")
    if i in range(31,61):
        duration_sec_list.append("30-60")
    if i in range(60,121):
        duration_sec_list.append("60-120")
    if i in range(120,241):
        duration_sec_list.append("120-240")
    if i > 240:
        duration_sec_list.append(">240")
        
duration_sec_list = pd.Series(duration_sec_list)
di = duration_sec_list.value_counts().index
dv = duration_sec_list.value_counts().values
sns.barplot(x=di,y=dv)

plt.xlabel("Encounter time in seconds",fontsize=24)
plt.xticks(fontsize=20)
plt.ylabel("Count",fontsize=24)
plt.yticks(fontsize=20)

plt.show()

# %% [markdown]
# ## Season VS Weekday

# %%
plt.subplots(figsize=(22,8))
ax = sns.countplot(x="event_weekday", hue="season", data=ufo_df)

# %% [markdown]
# ## Shape VS Season

# %%
plt.subplots(figsize=(22,8))
sns.countplot(x="season", hue="shape", order=['Spring', 'Summer', 'Autumn', 'Winter'], hue_order=['cylinder', 'light', 'circle', 'sphere', 'disk', 'fireball'], data=ufo_df)

# %% [markdown]
# ## Shape VS Color

# %%
plt.subplots(figsize=(22,8))
sns.countplot(x="ufo_color", hue="shape", order=['??', 'red', 'white', 'orange'], hue_order=['cylinder', 'light', 'circle', 'sphere', 'disk', 'fireball'], data=ufo_df)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

wordcloud = WordCloud().generate(' '.join(ufo_df['comments']))

plt.subplots(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ufo_df.columns
